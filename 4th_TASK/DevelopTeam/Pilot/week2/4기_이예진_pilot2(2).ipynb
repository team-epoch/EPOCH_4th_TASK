# %% [markdown]
# # **서울 공유 자전거 이용에 미치는 영향 분석**

# %% [markdown]
# 전처리
#
# 1. 변수명 수정
#
# 2. 변수 타입 수정
#
# 3. 결측치 처리
#
# 4. 중복값 처리
#
# 5. 이상치 처리
#
# 6. 데이터 정리
#
# 7. Holiday 변수 숫자로 매핑
#
# 8. 파생 변수 생성

# %% [markdown]
# **데이터 불러오기**

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
path0 = '/content/drive/MyDrive/에폭/SeoulBikeData.csv'

df = pd.read_csv(path0, encoding='cp949')
df.head()
# Out:
#          Date  Rented Bike Count  Hour  Temperature(캜)  Humidity(%)  \
# 0  01/12/2017                254     0            -5.2           37
# 1  01/12/2017                204     1            -5.5           38
# 2  01/12/2017                173     2            -6.0           39
# 3  01/12/2017                107     3            -6.2           40
# 4  01/12/2017                 78     4            -6.0           36
#
#    Wind speed (m/s)  Visibility (10m)  Dew point temperature(캜)  \
# 0               2.2              2000                     -17.6
# 1               0.8              2000                     -17.6
# 2               1.0              2000                     -17.7
# 3               0.9              2000                     -17.6
# 4               2.3              2000                     -18.6
#
#    Solar Radiation (MJ/m2)  Rainfall(mm)  Snowfall (cm) Seasons     Holiday  \
# 0                      0.0           0.0            0.0  Winter  No Holiday
# 1                      0.0           0.0            0.0  Winter  No Holiday
# 2                      0.0           0.0            0.0  Winter  No Holiday
# 3                      0.0           0.0            0.0  Winter  No Holiday
# 4                      0.0           0.0            0.0  Winter  No Holiday
#
#   Functioning Day
# 0             Yes
# 1             Yes
# 2             Yes
# 3             Yes
# 4             Yes

# %% [markdown]
# ### **변수명 수정**

# %% [markdown]
# **변수명의 '캜' > '℃'로 변경**

# %%
df.rename(columns={'Temperature(캜)': 'Temperature(°C)', 'Dew point temperature(캜)': 'Dew point temperature(°C)'}, inplace=True)
df.head()
# Out:
#          Date  Rented Bike Count  Hour  Temperature(°C)  Humidity(%)  \
# 0  01/12/2017                254     0             -5.2           37
# 1  01/12/2017                204     1             -5.5           38
# 2  01/12/2017                173     2             -6.0           39
# 3  01/12/2017                107     3             -6.2           40
# 4  01/12/2017                 78     4             -6.0           36
#
#    Wind speed (m/s)  Visibility (10m)  Dew point temperature(°C)  \
# 0               2.2              2000                      -17.6
# 1               0.8              2000                      -17.6
# 2               1.0              2000                      -17.7
# 3               0.9              2000                      -17.6
# 4               2.3              2000                      -18.6
#
#    Solar Radiation (MJ/m2)  Rainfall(mm)  Snowfall (cm) Seasons     Holiday  \
# 0                      0.0           0.0            0.0  Winter  No Holiday
# 1                      0.0           0.0            0.0  Winter  No Holiday
# 2                      0.0           0.0            0.0  Winter  No Holiday
# 3                      0.0           0.0            0.0  Winter  No Holiday
# 4                      0.0           0.0            0.0  Winter  No Holiday
#
#   Functioning Day
# 0             Yes
# 1             Yes
# 2             Yes
# 3             Yes
# 4             Yes

# %% [markdown]
# **Functioning Day 변수명 변경**
#
# 변수 설명에는 Functional Day로 작성되어 있어 통일시키기

# %%
df.rename(columns={'Functioning Day': 'Functional Day'}, inplace=True)
df.head()
# Out:
#          Date  Rented Bike Count  Hour  Temperature(°C)  Humidity(%)  \
# 0  01/12/2017                254     0             -5.2           37
# 1  01/12/2017                204     1             -5.5           38
# 2  01/12/2017                173     2             -6.0           39
# 3  01/12/2017                107     3             -6.2           40
# 4  01/12/2017                 78     4             -6.0           36
#
#    Wind speed (m/s)  Visibility (10m)  Dew point temperature(°C)  \
# 0               2.2              2000                      -17.6
# 1               0.8              2000                      -17.6
# 2               1.0              2000                      -17.7
# 3               0.9              2000                      -17.6
# 4               2.3              2000                      -18.6
#
#    Solar Radiation (MJ/m2)  Rainfall(mm)  Snowfall (cm) Seasons     Holiday  \
# 0                      0.0           0.0            0.0  Winter  No Holiday
# 1                      0.0           0.0            0.0  Winter  No Holiday
# 2                      0.0           0.0            0.0  Winter  No Holiday
# 3                      0.0           0.0            0.0  Winter  No Holiday
# 4                      0.0           0.0            0.0  Winter  No Holiday
#
#   Functional Day
# 0            Yes
# 1            Yes
# 2            Yes
# 3            Yes
# 4            Yes

# %% [markdown]
# ### **변수 타입 수정하기**

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8760 entries, 0 to 8759
# Data columns (total 14 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Date                       8760 non-null   object
#  1   Rented Bike Count          8760 non-null   int64
#  2   Hour                       8760 non-null   int64
#  3   Temperature(°C)            8760 non-null   float64
#  4   Humidity(%)                8760 non-null   int64
#  5   Wind speed (m/s)           8760 non-null   float64
#  6   Visibility (10m)           8760 non-null   int64
#  7   Dew point temperature(°C)  8760 non-null   float64
#  8   Solar Radiation (MJ/m2)    8760 non-null   float64
#  9   Rainfall(mm)               8760 non-null   float64
#  10  Snowfall (cm)              8760 non-null   float64
#  11  Seasons                    8760 non-null   object
#  12  Holiday                    8760 non-null   object
#  13  Functional Day             8760 non-null   object
# dtypes: float64(6), int64(4), object(4)
# memory usage: 958.3+ KB

# %% [markdown]
# 날짜 변수(Date)와 시간대 변수(Hour)의 데이터 타입 변경

# %% [markdown]
# **(1) Date변수 데이터 타입 object에서 datetime으로 변환**

# %% [markdown]
# Date변수 바꿔주기(연도-월-일 형태)
#
# 현재 데이터 형식이 일/월/연도이므로 dayfirst=True

# %%
df["Date"] = pd.to_datetime(df["Date"], dayfirst=True)
df.head()
# Out:
#         Date  Rented Bike Count  Hour  Temperature(°C)  Humidity(%)  \
# 0 2017-12-01                254     0             -5.2           37
# 1 2017-12-01                204     1             -5.5           38
# 2 2017-12-01                173     2             -6.0           39
# 3 2017-12-01                107     3             -6.2           40
# 4 2017-12-01                 78     4             -6.0           36
#
#    Wind speed (m/s)  Visibility (10m)  Dew point temperature(°C)  \
# 0               2.2              2000                      -17.6
# 1               0.8              2000                      -17.6
# 2               1.0              2000                      -17.7
# 3               0.9              2000                      -17.6
# 4               2.3              2000                      -18.6
#
#    Solar Radiation (MJ/m2)  Rainfall(mm)  Snowfall (cm) Seasons     Holiday  \
# 0                      0.0           0.0            0.0  Winter  No Holiday
# 1                      0.0           0.0            0.0  Winter  No Holiday
# 2                      0.0           0.0            0.0  Winter  No Holiday
# 3                      0.0           0.0            0.0  Winter  No Holiday
# 4                      0.0           0.0            0.0  Winter  No Holiday
#
#   Functional Day
# 0            Yes
# 1            Yes
# 2            Yes
# 3            Yes
# 4            Yes

# %% [markdown]
# **(2) Hour변수 데이터타입 int64에서 object로 변환**

# %%
df["Hour"] = df["Hour"].astype(str)

# %% [markdown]
# ### **결측치 처리**

# %%
df.isnull().sum()
# Out:
# Date                         0
# Rented Bike Count            0
# Hour                         0
# Temperature(°C)              0
# Humidity(%)                  0
# Wind speed (m/s)             0
# Visibility (10m)             0
# Dew point temperature(°C)    0
# Solar Radiation (MJ/m2)      0
# Rainfall(mm)                 0
# Snowfall (cm)                0
# Seasons                      0
# Holiday                      0
# Functional Day               0
# dtype: int64

# %% [markdown]
# 결측치가 없음

# %% [markdown]
# ### **중복값 처리**

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# 중복값 없음

# %% [markdown]
# ### **이상치 처리**

# %%
numerical_cols = df[df.columns[(df.dtypes == 'float64') | (df.dtypes == 'int64')]]

# %%
numerical_cols.describe()
# Out:
#        Rented Bike Count  Temperature(°C)  Humidity(%)  Wind speed (m/s)  \
# count        8760.000000      8760.000000  8760.000000       8760.000000
# mean          704.602055        12.882922    58.226256          1.724909
# std           644.997468        11.944825    20.362413          1.036300
# min             0.000000       -17.800000     0.000000          0.000000
# 25%           191.000000         3.500000    42.000000          0.900000
# 50%           504.500000        13.700000    57.000000          1.500000
# 75%          1065.250000        22.500000    74.000000          2.300000
# max          3556.000000        39.400000    98.000000          7.400000
#
#        Visibility (10m)  Dew point temperature(°C)  Solar Radiation (MJ/m2)  \
# count       8760.000000                8760.000000              8760.000000
# mean        1436.825799                   4.073813                 0.569111
# std          608.298712                  13.060369                 0.868746
# min           27.000000                 -30.600000                 0.000000
# 25%          940.000000                  -4.700000                 0.000000
# 50%         1698.000000                   5.100000                 0.010000
# 75%         2000.000000                  14.800000                 0.930000
# max         2000.000000                  27.200000                 3.520000
#
#        Rainfall(mm)  Snowfall (cm)
# count   8760.000000    8760.000000
# mean       0.148687       0.075068
# std        1.128193       0.436746
# min        0.000000       0.000000
# 25%        0.000000       0.000000
# 50%        0.000000       0.000000
# 75%        0.000000       0.000000
# max       35.000000       8.800000

# %% [markdown]
# ### **데이터 정리**

# %% [markdown]
# **Functional Day 변수 NoFunc값 결측치 처리 여부 확인**

# %% [markdown]
# Functional Day - NoFunc(Non Functional Hours), Fun(Functional hours)

# %%
NFD=df[df['Functional Day'] == "No"] #운영하지 않는 시간대 출력
NFD
# Out:
#            Date  Rented Bike Count Hour  Temperature(°C)  Humidity(%)  \
# 3144 2018-04-11                  0    0             14.4           82
# 3145 2018-04-11                  0    1             13.6           81
# 3146 2018-04-11                  0    2             12.7           80
# 3147 2018-04-11                  0    3             11.6           81
# 3148 2018-04-11                  0    4             10.2           83
# ...         ...                ...  ...              ...          ...
# 8251 2018-11-09                  0   19             11.9           71
# 8252 2018-11-09                  0   20             11.9           72
# 8253 2018-11-09                  0   21             11.4           74
# 8254 2018-11-09                  0   22             11.2           75
# 8255 2018-11-09                  0   23             10.9           76
#
#       Wind speed (m/s)  Visibility (10m)  Dew point temperature(°C)  \
# 3144               4.6              1041                       11.3
# 3145               3.6               886                       10.3
# 3146               3.9               885                        9.3
# 3147               3.1               687                        8.4
# 3148               3.5               554                        7.4
# ...                ...               ...                        ...
# 8251               2.7               589                        6.7
# 8252               2.5               526                        7.0
# 8253               1.9               498                        6.9
# 8254               1.7               478                        6.9
# 8255               1.2               456                        6.8
#
#       Solar Radiation (MJ/m2)  Rainfall(mm)  Snowfall (cm) Seasons  \
# 3144                      0.0           0.0            0.0  Spring
# 3145                      0.0           0.0            0.0  Spring
# 3146                      0.0           0.0            0.0  Spring
# 3147                      0.0           0.0            0.0  Spring
# 3148                      0.0           0.0            0.0  Spring
# ...                       ...           ...            ...     ...
# 8251                      0.0           0.0            0.0  Autumn
# 8252                      0.0           0.0            0.0  Autumn
# 8253                      0.0           0.0            0.0  Autumn
# 8254                      0.0           0.0            0.0  Autumn
# 8255                      0.0           0.0            0.0  Autumn
#
#          Holiday Functional Day
# 3144  No Holiday             No
# 3145  No Holiday             No
# 3146  No Holiday             No
# 3147  No Holiday             No
# 3148  No Holiday             No
# ...          ...            ...
# 8251  No Holiday             No
# 8252  No Holiday             No
# 8253  No Holiday             No
# 8254  No Holiday             No
# 8255  No Holiday             No
#
# [295 rows x 14 columns]

# %% [markdown]
# 일년 중 295개의 시간대에 운영하지 않음

# %%
count_per_date = NFD.groupby('Date').size().reset_index(name='count') #날짜별 운영 안한 시간대
print(count_per_date)
# Out:
#          Date  count
# 0  2018-04-11     24
# 1  2018-05-10     24
# 2  2018-09-18     24
# 3  2018-09-19     24
# 4  2018-09-28     24
# 5  2018-09-30     24
# 6  2018-10-02     24
# 7  2018-10-04     24
# 8  2018-10-06      7
# 9  2018-10-09     24
# 10 2018-11-03     24
# 11 2018-11-06     24
# 12 2018-11-09     24

# %%
count_per_date["DayOfWeek"] = count_per_date["Date"].dt.day_name() #요일 출력
print(count_per_date)
# Out:
#          Date  count  DayOfWeek
# 0  2018-04-11     24  Wednesday
# 1  2018-05-10     24   Thursday
# 2  2018-09-18     24    Tuesday
# 3  2018-09-19     24  Wednesday
# 4  2018-09-28     24     Friday
# 5  2018-09-30     24     Sunday
# 6  2018-10-02     24    Tuesday
# 7  2018-10-04     24   Thursday
# 8  2018-10-06      7   Saturday
# 9  2018-10-09     24    Tuesday
# 10 2018-11-03     24   Saturday
# 11 2018-11-06     24    Tuesday
# 12 2018-11-09     24     Friday

# %% [markdown]
# 특정 요일에 운영하지 않은 것이 아님.

# %% [markdown]
# 운영 안한 날 각 날씨 변수 평균

# %%
FD_date_list = count_per_date["Date"].tolist()
print(FD_date_list)
# Out:
# [Timestamp('2018-04-11 00:00:00'), Timestamp('2018-05-10 00:00:00'), Timestamp('2018-09-18 00:00:00'), Timestamp('2018-09-19 00:00:00'), Timestamp('2018-09-28 00:00:00'), Timestamp('2018-09-30 00:00:00'), Timestamp('2018-10-02 00:00:00'), Timestamp('2018-10-04 00:00:00'), Timestamp('2018-10-06 00:00:00'), Timestamp('2018-10-09 00:00:00'), Timestamp('2018-11-03 00:00:00'), Timestamp('2018-11-06 00:00:00'), Timestamp('2018-11-09 00:00:00')]

# %%
df_selected = df[df["Date"].isin(FD_date_list)]

numerical_cols = df_selected.select_dtypes(include=["float64", "int64"])

df_mean = df_selected.groupby("Date")[numerical_cols.columns].mean()
df_mean
# Out:
#             Rented Bike Count  Temperature(°C)  Humidity(%)  Wind speed (m/s)  \
# Date
# 2018-04-11           0.000000        12.866667    53.375000          3.008333
# 2018-05-10           0.000000        15.470833    65.833333          2.254167
# 2018-09-18           0.000000        21.850000    59.666667          1.329167
# 2018-09-19           0.000000        22.204167    59.750000          0.950000
# 2018-09-28           0.000000        17.525000    57.291667          1.295833
# 2018-09-30           0.000000        17.916667    53.791667          2.025000
# 2018-10-02           0.000000        15.783333    60.791667          1.629167
# 2018-10-04           0.000000        18.895833    56.833333          1.287500
# 2018-10-06         668.208333        18.020833    84.166667          2.191667
# 2018-10-09           0.000000        15.000000    52.625000          1.137500
# 2018-11-03           0.000000        11.258333    56.458333          1.237500
# 2018-11-06           0.000000        12.137500    69.791667          0.908333
# 2018-11-09           0.000000        12.029167    70.750000          3.054167
#
#             Visibility (10m)  Dew point temperature(°C)  \
# Date
# 2018-04-11       1331.541667                   2.120833
# 2018-05-10       1099.958333                   8.700000
# 2018-09-18       1819.125000                  13.058333
# 2018-09-19       1729.208333                  13.591667
# 2018-09-28       1999.333333                   8.833333
# 2018-09-30       1928.250000                   7.600000
# 2018-10-02       1843.708333                   7.541667
# 2018-10-04       1956.125000                   9.591667
# 2018-10-06       1532.208333                  15.087500
# 2018-10-09       1992.583333                   5.008333
# 2018-11-03       1070.166667                   1.937500
# 2018-11-06        409.666667                   6.525000
# 2018-11-09       1126.250000                   6.566667
#
#             Solar Radiation (MJ/m2)  Rainfall(mm)  Snowfall (cm)
# Date
# 2018-04-11                 1.035833      0.000000            0.0
# 2018-05-10                 1.105417      0.000000            0.0
# 2018-09-18                 0.660417      0.000000            0.0
# 2018-09-19                 0.444167      0.008333            0.0
# 2018-09-28                 0.365000      0.000000            0.0
# 2018-09-30                 0.706250      0.000000            0.0
# 2018-10-02                 0.785000      0.000000            0.0
# 2018-10-04                 0.661667      0.000000            0.0
# 2018-10-06                 0.285833      2.354167            0.0
# 2018-10-09                 0.370417      0.000000            0.0
# 2018-11-03                 0.566250      0.000000            0.0
# 2018-11-06                 0.327083      0.000000            0.0
# 2018-11-09                 0.406250      0.791667            0.0

# %%
df.describe() #위 데이터에 이상값이 있는지 확인하기 위해 출력
# Out:
#                                 Date  Rented Bike Count  Temperature(°C)  \
# count                           8760        8760.000000      8760.000000
# mean   2018-05-31 23:59:59.999999744         704.602055        12.882922
# min              2017-12-01 00:00:00           0.000000       -17.800000
# 25%              2018-03-02 00:00:00         191.000000         3.500000
# 50%              2018-06-01 00:00:00         504.500000        13.700000
# 75%              2018-08-31 00:00:00        1065.250000        22.500000
# max              2018-11-30 00:00:00        3556.000000        39.400000
# std                              NaN         644.997468        11.944825
#
#        Humidity(%)  Wind speed (m/s)  Visibility (10m)  \
# count  8760.000000       8760.000000       8760.000000
# mean     58.226256          1.724909       1436.825799
# min       0.000000          0.000000         27.000000
# 25%      42.000000          0.900000        940.000000
# 50%      57.000000          1.500000       1698.000000
# 75%      74.000000          2.300000       2000.000000
# max      98.000000          7.400000       2000.000000
# std      20.362413          1.036300        608.298712
#
#        Dew point temperature(°C)  Solar Radiation (MJ/m2)  Rainfall(mm)  \
# count                8760.000000              8760.000000   8760.000000
# mean                    4.073813                 0.569111      0.148687
# min                   -30.600000                 0.000000      0.000000
# 25%                    -4.700000                 0.000000      0.000000
# 50%                     5.100000                 0.010000      0.000000
# 75%                    14.800000                 0.930000      0.000000
# max                    27.200000                 3.520000     35.000000
# std                    13.060369                 0.868746      1.128193
#
#        Snowfall (cm)
# count    8760.000000
# mean        0.075068
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         0.000000
# max         8.800000
# std         0.436746

# %% [markdown]
# 해당 날짜들은 특별히 날씨가 특이한 날이 아니기에 기상 악화로 인해 운영 중단한 것이라고 볼 수 없음.
#
# 점검이나 데이터 수집 오류로 인해 Functional Day가 아닌 것으로 추정.
#
# **Non-Functional Day는 공유 자전거 이용량 분석에 왜곡을 일으킬 수 있으므로, 제거하는 것이 적절하다고 판단.**

# %%
df.shape
# Out:
# (8760, 14)

# %%
df = df[df["Functional Day"] != "No"] #제거

# %%
df.shape
# Out:
# (8465, 14)

# %%
df.drop(columns=["Functional Day"], inplace=True)#Functional Day 변수 삭제

# %%
df
# Out:
#            Date  Rented Bike Count Hour  Temperature(°C)  Humidity(%)  \
# 0    2017-12-01                254    0             -5.2           37
# 1    2017-12-01                204    1             -5.5           38
# 2    2017-12-01                173    2             -6.0           39
# 3    2017-12-01                107    3             -6.2           40
# 4    2017-12-01                 78    4             -6.0           36
# ...         ...                ...  ...              ...          ...
# 8755 2018-11-30               1003   19              4.2           34
# 8756 2018-11-30                764   20              3.4           37
# 8757 2018-11-30                694   21              2.6           39
# 8758 2018-11-30                712   22              2.1           41
# 8759 2018-11-30                584   23              1.9           43
#
#       Wind speed (m/s)  Visibility (10m)  Dew point temperature(°C)  \
# 0                  2.2              2000                      -17.6
# 1                  0.8              2000                      -17.6
# 2                  1.0              2000                      -17.7
# 3                  0.9              2000                      -17.6
# 4                  2.3              2000                      -18.6
# ...                ...               ...                        ...
# 8755               2.6              1894                      -10.3
# 8756               2.3              2000                       -9.9
# 8757               0.3              1968                       -9.9
# 8758               1.0              1859                       -9.8
# 8759               1.3              1909                       -9.3
#
#       Solar Radiation (MJ/m2)  Rainfall(mm)  Snowfall (cm) Seasons     Holiday
# 0                         0.0           0.0            0.0  Winter  No Holiday
# 1                         0.0           0.0            0.0  Winter  No Holiday
# 2                         0.0           0.0            0.0  Winter  No Holiday
# 3                         0.0           0.0            0.0  Winter  No Holiday
# 4                         0.0           0.0            0.0  Winter  No Holiday
# ...                       ...           ...            ...     ...         ...
# 8755                      0.0           0.0            0.0  Autumn  No Holiday
# 8756                      0.0           0.0            0.0  Autumn  No Holiday
# 8757                      0.0           0.0            0.0  Autumn  No Holiday
# 8758                      0.0           0.0            0.0  Autumn  No Holiday
# 8759                      0.0           0.0            0.0  Autumn  No Holiday
#
# [8465 rows x 13 columns]

# %% [markdown]
# ### **Holiday 변수 숫자로 매핑**

# %%
df["Holiday_dummy"] = df["Holiday"].map({"No Holiday":0, "Holiday":1})
df.head()
# Out:
#         Date  Rented Bike Count Hour  Temperature(°C)  Humidity(%)  \
# 0 2017-12-01                254    0             -5.2           37
# 1 2017-12-01                204    1             -5.5           38
# 2 2017-12-01                173    2             -6.0           39
# 3 2017-12-01                107    3             -6.2           40
# 4 2017-12-01                 78    4             -6.0           36
#
#    Wind speed (m/s)  Visibility (10m)  Dew point temperature(°C)  \
# 0               2.2              2000                      -17.6
# 1               0.8              2000                      -17.6
# 2               1.0              2000                      -17.7
# 3               0.9              2000                      -17.6
# 4               2.3              2000                      -18.6
#
#    Solar Radiation (MJ/m2)  Rainfall(mm)  Snowfall (cm) Seasons     Holiday  \
# 0                      0.0           0.0            0.0  Winter  No Holiday
# 1                      0.0           0.0            0.0  Winter  No Holiday
# 2                      0.0           0.0            0.0  Winter  No Holiday
# 3                      0.0           0.0            0.0  Winter  No Holiday
# 4                      0.0           0.0            0.0  Winter  No Holiday
#
#   Day of Week  Holiday_dummy
# 0      Friday              0
# 1      Friday              0
# 2      Friday              0
# 3      Friday              0
# 4      Friday              0

# %%
df.drop(columns=["Holiday"],inplace=True)
df.rename(columns={"Holiday_dummy": "Holiday"},inplace=True)

df.head()
# Out:
#         Date  Rented Bike Count Hour  Temperature(°C)  Humidity(%)  \
# 0 2017-12-01                254    0             -5.2           37
# 1 2017-12-01                204    1             -5.5           38
# 2 2017-12-01                173    2             -6.0           39
# 3 2017-12-01                107    3             -6.2           40
# 4 2017-12-01                 78    4             -6.0           36
#
#    Wind speed (m/s)  Visibility (10m)  Dew point temperature(°C)  \
# 0               2.2              2000                      -17.6
# 1               0.8              2000                      -17.6
# 2               1.0              2000                      -17.7
# 3               0.9              2000                      -17.6
# 4               2.3              2000                      -18.6
#
#    Solar Radiation (MJ/m2)  Rainfall(mm)  Snowfall (cm) Seasons Day of Week  \
# 0                      0.0           0.0            0.0  Winter      Friday
# 1                      0.0           0.0            0.0  Winter      Friday
# 2                      0.0           0.0            0.0  Winter      Friday
# 3                      0.0           0.0            0.0  Winter      Friday
# 4                      0.0           0.0            0.0  Winter      Friday
#
#    Holiday
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0

# %% [markdown]
# ### **파생 변수 생성**

# %% [markdown]
# **요일 변수 생성**

# %%
#요일 변수 생성
df["Day of Week"] = df["Date"].dt.day_name()
df.head()
# Out:
#         Date  Rented Bike Count Hour  Temperature(°C)  Humidity(%)  \
# 0 2017-12-01                254    0             -5.2           37
# 1 2017-12-01                204    1             -5.5           38
# 2 2017-12-01                173    2             -6.0           39
# 3 2017-12-01                107    3             -6.2           40
# 4 2017-12-01                 78    4             -6.0           36
#
#    Wind speed (m/s)  Visibility (10m)  Dew point temperature(°C)  \
# 0               2.2              2000                      -17.6
# 1               0.8              2000                      -17.6
# 2               1.0              2000                      -17.7
# 3               0.9              2000                      -17.6
# 4               2.3              2000                      -18.6
#
#    Solar Radiation (MJ/m2)  Rainfall(mm)  Snowfall (cm) Seasons     Holiday  \
# 0                      0.0           0.0            0.0  Winter  No Holiday
# 1                      0.0           0.0            0.0  Winter  No Holiday
# 2                      0.0           0.0            0.0  Winter  No Holiday
# 3                      0.0           0.0            0.0  Winter  No Holiday
# 4                      0.0           0.0            0.0  Winter  No Holiday
#
#   Day of Week
# 0      Friday
# 1      Friday
# 2      Friday
# 3      Friday
# 4      Friday

# %% [markdown]
# ***주말 여부 변수 생성***

# %%
df["Weekend"] = np.where(df["Day of Week"].isin(["Saturday", "Sunday"]), 1, 0)
df
# Out:
#            Date  Rented Bike Count Hour  Temperature(°C)  Humidity(%)  \
# 0    2017-12-01                254    0             -5.2           37
# 1    2017-12-01                204    1             -5.5           38
# 2    2017-12-01                173    2             -6.0           39
# 3    2017-12-01                107    3             -6.2           40
# 4    2017-12-01                 78    4             -6.0           36
# ...         ...                ...  ...              ...          ...
# 8755 2018-11-30               1003   19              4.2           34
# 8756 2018-11-30                764   20              3.4           37
# 8757 2018-11-30                694   21              2.6           39
# 8758 2018-11-30                712   22              2.1           41
# 8759 2018-11-30                584   23              1.9           43
#
#       Wind speed (m/s)  Visibility (10m)  Dew point temperature(°C)  \
# 0                  2.2              2000                      -17.6
# 1                  0.8              2000                      -17.6
# 2                  1.0              2000                      -17.7
# 3                  0.9              2000                      -17.6
# 4                  2.3              2000                      -18.6
# ...                ...               ...                        ...
# 8755               2.6              1894                      -10.3
# 8756               2.3              2000                       -9.9
# 8757               0.3              1968                       -9.9
# 8758               1.0              1859                       -9.8
# 8759               1.3              1909                       -9.3
#
#       Solar Radiation (MJ/m2)  Rainfall(mm)  Snowfall (cm) Seasons  \
# 0                         0.0           0.0            0.0  Winter
# 1                         0.0           0.0            0.0  Winter
# 2                         0.0           0.0            0.0  Winter
# 3                         0.0           0.0            0.0  Winter
# 4                         0.0           0.0            0.0  Winter
# ...                       ...           ...            ...     ...
# 8755                      0.0           0.0            0.0  Autumn
# 8756                      0.0           0.0            0.0  Autumn
# 8757                      0.0           0.0            0.0  Autumn
# 8758                      0.0           0.0            0.0  Autumn
# 8759                      0.0           0.0            0.0  Autumn
#
#      Day of Week  Holiday  Weekend
# 0         Friday        0        0
# 1         Friday        0        0
# 2         Friday        0        0
# 3         Friday        0        0
# 4         Friday        0        0
# ...          ...      ...      ...
# 8755      Friday        0        0
# 8756      Friday        0        0
# 8757      Friday        0        0
# 8758      Friday        0        0
# 8759      Friday        0        0
#
# [8465 rows x 15 columns]
